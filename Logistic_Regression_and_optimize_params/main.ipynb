# %% [markdown]
# # Logistic Regression and methods for optimize params
#
# --------------------------

# %% [markdown]
# Links for understand topic:
# * Stanford CS299: https://www.youtube.com/watch?v=4b4MUYve_U8&list=PLoROMvodv4rMiGQp3WXShtMGgzqpfVfbU&index=2
